# %%
import gym
import gym_anytrading

env = gym.make('forex-v0', frame_bound=(50, 2000), window_size=10)

# %%
env.reset()
env.render()

# %%
from gym_anytrading.envs import TradingEnv, ForexEnv, StocksEnv, Actions, Positions 
from gym_anytrading.datasets import FOREX_EURUSD_1H_ASK, STOCKS_GOOGL
import matplotlib.pyplot as plt
observation = env.reset()
while True:
    action = env.action_space.sample()
    observation, reward, done, info = env.step(action)
    # env.render()
    if done:
        print(observation)
        print("info:", info)
        break

plt.cla()
env.render_all()
plt.show()
# Out:
# [[ 1.08977e+00 -1.00000e-05]
#  [ 1.09073e+00  9.60000e-04]
#  [ 1.09039e+00 -3.40000e-04]
#  [ 1.09054e+00  1.50000e-04]
#  [ 1.09090e+00  3.60000e-04]
#  [ 1.09087e+00 -3.00000e-05]
#  [ 1.09070e+00 -1.70000e-04]
#  [ 1.09097e+00  2.70000e-04]
#  [ 1.09105e+00  8.00000e-05]
#  [ 1.09091e+00 -1.40000e-04]]
# info: {'total_reward': 273.3999999999901, 'total_profit': 0.8602945398121838, 'position': 1}

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Flatten, Dropout, Input, Concatenate
from keras.optimizers import Adam

from rl.agents.dqn import DQNAgent
from rl.agents.ddpg import DDPGAgent
from rl.policy import BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.random import OrnsteinUhlenbeckProcess
from rl.callbacks import FileLogger, ModelIntervalCheckpoint, TrainEpisodeLogger

from sklearn import preprocessing
import warnings
warnings.filterwarnings('ignore')

# %%
import json
import numpy as np

class FileEpisodeLogger(TrainEpisodeLogger):
    def __init__(self, filepath):
        TrainEpisodeLogger.__init__(self)
        self.filepath = filepath
        
    def on_episode_end(self, episode, logs):
        episode_steps = len(self.observations[episode])
        variables = [episode+1, episode_steps, np.sum(self.rewards[episode]), np.mean(self.rewards[episode]), np.mean(self.actions[episode])]
        row = ''
        for var in variables:
            row += '{},'.format(var)
        # Overwrite already open file. We can simply seek to the beginning since the file will
        # grow strictly monotonously.
        with open(self.filepath,'a') as fd:
            fd.write(row[:-1] + '\n')

# %%
class EnvProcessor(Processor):
    def process_observation(self, observation):
        assert observation.ndim == 2  # (height, width, channel)
        return self.process_obs_1(observation)
    
    def process_obs_1(self, observation):
        prices = []
        diff = []
        for o in observation:
            prices.append(o[0])
            diff.append(o[1])
        prices = preprocessing.normalize([prices], norm='l2', axis=1, copy=True, return_norm=False)[0]
        diff = preprocessing.normalize([diff], norm='l2', axis=1, copy=True, return_norm=False)[0]
        new_obs = np.column_stack((prices, diff))
        return new_obs
    
    def process_obs_2(self, observation):
        prices = []
        diff = []
        for o in observation:
            prices.append(o[0])
            diff.append(o[1] / o[0] * 100)
        prices = preprocessing.normalize([prices], norm='l2', axis=1, copy=True, return_norm=False)[0]
        new_obs = np.column_stack((prices, diff))
        return new_obs
        
    def process_state_batch(self, batch):
#         print(batch)
        return batch

    def process_reward(self, reward):
        return reward

class DDPGEnvProcessor(EnvProcessor):
    def process_action(self,action):
        return np.argmax(action)
    
class CustomEpsGreedyQPolicy(EpsGreedyQPolicy):
    def __init__(self, eps=0.1, update_interval=100):
        EpsGreedyQPolicy.__init__(self, eps)
        self.update_interval = update_interval
        self.count = 0
        self.init_eps = self.eps
        
    def select_action(self, q_values):
        assert q_values.ndim == 1
        nb_actions = q_values.shape[0]

        if np.random.uniform() < self.eps:
            action = np.random.randint(0, nb_actions)
        else:
            action = np.argmax(q_values)
        self.count += 1
        if (self.count % self.update_interval) == 0:
            self.eps = self.init_eps / (self.count / self.update_interval)
            print(self.eps)
        return action

# %%
nb_actions = env.action_space.n

# Next, we build a very simple model.
model = Sequential()
model.add(Flatten(input_shape=(1,) + env.observation_space.shape))
model.add(Dropout(0.2))
model.add(Dense(32))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Dense(16))
model.add(Activation('relu'))
model.add(Dense(nb_actions))
model.add(Activation('softmax'))
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_80 (Flatten)         (None, 20)                0
# _________________________________________________________________
# dropout_107 (Dropout)        (None, 20)                0
# _________________________________________________________________
# dense_235 (Dense)            (None, 32)                672
# _________________________________________________________________
# activation_235 (Activation)  (None, 32)                0
# _________________________________________________________________
# dropout_108 (Dropout)        (None, 32)                0
# _________________________________________________________________
# dense_236 (Dense)            (None, 16)                528
# _________________________________________________________________
# activation_236 (Activation)  (None, 16)                0
# _________________________________________________________________
# dense_237 (Dense)            (None, 2)                 34
# _________________________________________________________________
# activation_237 (Activation)  (None, 2)                 0
# =================================================================
# Total params: 1,234
# Trainable params: 1,234
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# 3 = enable_double_dqn=True, nb_steps=1000000, EpsGreedyQPolicy **
# 4 = enable_double_dqn=True, nb_steps=100000, EpsGreedyQPolicy
# 5 = enable_double_dqn=True, nb_steps=100000, BoltzmannQPolicy **
# 6 = enable_double_dqn=True, nb_steps=1000000, CustomEpsGreedyQPolicy, process_obs_2
# 7 = enable_double_dqn=True, nb_steps=1000000, EpsGreedyQPolicy, process_obs_2 **
# 8 = enable_double_dqn=True, nb_steps=1000000, CustomEpsGreedyQPolicy **
# 9 = enable_double_dqn=True, nb_steps=1000000, CustomEpsGreedyQPolicy(update_interval=2500), train_interval=256, batch_size=512
# 10 = enable_double_dqn=True, nb_steps=1000000, BoltzmannQPolicy, train_interval=256, batch_size=512 **
# 11 = DDPG, train_interval=256, batch_size=512 ***
# 12 = enable_double_dqn=True, nb_steps=1000000, BoltzmannQPolicy, train_interval=32, batch_size=64 
# 13 = DDPG, train_interval=128, batch_size=64 ***
# 14 = DDPG, train_interval=128, batch_size=256, lr = 0.01, target_model_update=0.01, gamma=0.9
# 15 = DDPG, train_interval=128, batch_size=256, lr = 0.0001, target_model_update=0.0001, gamma=0.9
train_no = 14
weights_filename = 'dqn_weights_{}.h5f'.format(train_no)
checkpoint_weights_filename = 'dqn_weights_{step}_'+'{}.h5f'.format(train_no)
log_filename = 'dqn_log_{}.csv'.format(train_no)
callbacks = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=250000)]
callbacks += [FileEpisodeLogger(log_filename)]

# %%
processor = EnvProcessor()
memory = SequentialMemory(limit=100000, window_length=1)
# policy = CustomEpsGreedyQPolicy(update_interval = 2500, eps = 1.0)
policy = BoltzmannQPolicy()
agent = DQNAgent(model=model, nb_actions=nb_actions, memory=memory, nb_steps_warmup=20,
               target_model_update=1e-2, policy=policy, batch_size=64, processor=processor, 
               train_interval=32, enable_double_dqn=True)
agent.compile(Adam(lr=1e-3), metrics=['mae'])

# %% [markdown]
# ## WIth DDPG

# %%
# Next, we build a very simple model.
actor = Sequential()
actor.add(Flatten(input_shape=(1,) + env.observation_space.shape))
actor.add(Dropout(0.2))
actor.add(Dense(32))
actor.add(Activation('relu'))
actor.add(Dropout(0.2))
actor.add(Dense(16))
actor.add(Activation('relu'))
actor.add(Dense(nb_actions))
actor.add(Activation('softmax'))
# print(actor.summary())

action_input = Input(shape=(nb_actions,), name='action_input')
observation_input = Input(shape=(1,) + env.observation_space.shape, name='observation_input')
flattened_observation = Flatten()(observation_input)
x = Concatenate()([action_input, flattened_observation])
x = Dropout(0.2)(x)
x = Dense(32)(x)
x = Activation('relu')(x)
x = Dropout(0.2)(x)
x = Dense(16)(x)
x = Activation('relu')(x)
x = Dense(1)(x)
x = Activation('softmax')(x)
critic = Model(inputs=[action_input, observation_input], outputs=x)
# print(critic.summary())

# %%
processor = DDPGEnvProcessor()
memory = SequentialMemory(limit=100000, window_length=1)
random_process = OrnsteinUhlenbeckProcess(size=nb_actions, theta=.15, mu=0., sigma=.3)
agent = DDPGAgent(nb_actions=nb_actions, actor=actor, critic=critic, critic_action_input=action_input,
                  memory=memory, nb_steps_warmup_critic=100, nb_steps_warmup_actor=100,
                  random_process=random_process,processor=processor, gamma=.9, target_model_update=1e-2, 
                  batch_size=256, train_interval=128)
agent.compile(Adam(lr=1e-2), metrics=['mae'])

# %%
agent.fit(env, nb_steps=1000000, callbacks=callbacks, visualize=False, verbose=2)
agent.save_weights('dqn_weights_{}_final.h5f'.format(train_no), overwrite=True)
# Out:
# Training for 1000000 steps ...
# Training for 1000000 steps ...
#    1949/1000000: episode: 1, duration: 29.422s, episode steps: 1949, steps per second: 66, episode reward: 158.000, mean reward: 0.081 [-214.900, 226.700], mean action: 0.119 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 88.213459, mean_absolute_error: 2.041250, mean_q: 1.000000
#    3898/1000000: episode: 2, duration: 7.090s, episode steps: 1949, steps per second: 275, episode reward: -95.000, mean reward: -0.049 [-270.600, 102.900], mean action: 0.226 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 30.976951, mean_absolute_error: 1.031042, mean_q: 1.000000
#    5847/1000000: episode: 3, duration: 6.988s, episode steps: 1949, steps per second: 279, episode reward: -217.400, mean reward: -0.112 [-149.400, 67.900], mean action: 0.578 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 59.096769, mean_absolute_error: 1.415703, mean_q: 1.000000
#    7796/1000000: episode: 4, duration: 6.707s, episode steps: 1949, steps per second: 291, episode reward: 103.300, mean reward: 0.053 [-120.700, 309.800], mean action: 0.946 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 39.874117, mean_absolute_error: 1.188646, mean_q: 1.000000
#    9745/1000000: episode: 5, duration: 5.000s, episode steps: 1949, steps per second: 390, episode reward: 311.800, mean reward: 0.160 [-54.600, 149.800], mean action: 0.177 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 41.502907, mean_absolute_error: 1.160498, mean_q: 1.000000
#   11694/1000000: episode: 6, duration: 4.892s, episode steps: 1949, steps per second: 398, episode reward: 161.700, mean reward: 0.083 [-72.000, 173.500], mean action: 0.825 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 32.440916, mean_absolute_error: 0.915000, mean_q: 1.000000
#   13643/1000000: episode: 7, duration: 4.911s, episode steps: 1949, steps per second: 397, episode reward: -434.800, mean reward: -0.223 [-143.700, 56.900], mean action: 0.349 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 43.332713, mean_absolute_error: 0.990781, mean_q: 1.000000
#   15592/1000000: episode: 8, duration: 4.877s, episode steps: 1949, steps per second: 400, episode reward: 561.800, mean reward: 0.288 [-188.700, 233.200], mean action: 0.544 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 32.493773, mean_absolute_error: 1.014818, mean_q: 1.000000
#   17541/1000000: episode: 9, duration: 6.336s, episode steps: 1949, steps per second: 308, episode reward: -344.000, mean reward: -0.177 [-126.900, 186.300], mean action: 0.729 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 11.527210, mean_absolute_error: 0.809546, mean_q: 1.000000
#   19490/1000000: episode: 10, duration: 6.529s, episode steps: 1949, steps per second: 299, episode reward: -28.500, mean reward: -0.015 [-106.400, 198.300], mean action: 0.836 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 37.403694, mean_absolute_error: 1.183698, mean_q: 1.000000
#   21439/1000000: episode: 11, duration: 6.073s, episode steps: 1949, steps per second: 321, episode reward: 112.300, mean reward: 0.058 [-101.600, 188.200], mean action: 0.252 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 19.550407, mean_absolute_error: 0.919089, mean_q: 1.000000
#   23388/1000000: episode: 12, duration: 6.095s, episode steps: 1949, steps per second: 320, episode reward: -105.500, mean reward: -0.054 [-229.000, 73.300], mean action: 0.091 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 11.240379, mean_absolute_error: 0.737396, mean_q: 1.000000
#   25337/1000000: episode: 13, duration: 6.433s, episode steps: 1949, steps per second: 303, episode reward: 263.600, mean reward: 0.135 [-155.400, 93.100], mean action: 0.822 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 13.753356, mean_absolute_error: 0.899557, mean_q: 1.000000
#   27286/1000000: episode: 14, duration: 6.122s, episode steps: 1949, steps per second: 318, episode reward: -239.200, mean reward: -0.123 [-200.600, 52.200], mean action: 0.091 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 51.976103, mean_absolute_error: 1.035620, mean_q: 1.000000
#   29235/1000000: episode: 15, duration: 5.832s, episode steps: 1949, steps per second: 334, episode reward: 559.700, mean reward: 0.287 [-122.000, 137.500], mean action: 0.367 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 23.564406, mean_absolute_error: 0.905469, mean_q: 1.000000
#   31184/1000000: episode: 16, duration: 16.873s, episode steps: 1949, steps per second: 116, episode reward: -686.300, mean reward: -0.352 [-288.800, 66.100], mean action: 0.666 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 26.343338, mean_absolute_error: 0.949271, mean_q: 1.000000
#   33133/1000000: episode: 17, duration: 6.687s, episode steps: 1949, steps per second: 291, episode reward: -89.000, mean reward: -0.046 [-124.300, 115.700], mean action: 0.384 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 42.729843, mean_absolute_error: 1.120391, mean_q: 1.000000
#   35082/1000000: episode: 18, duration: 7.534s, episode steps: 1949, steps per second: 259, episode reward: 565.000, mean reward: 0.290 [-117.400, 96.600], mean action: 0.422 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 19.307768, mean_absolute_error: 0.913525, mean_q: 1.000000
#   37031/1000000: episode: 19, duration: 7.199s, episode steps: 1949, steps per second: 271, episode reward: 197.000, mean reward: 0.101 [-127.900, 101.400], mean action: 0.548 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 12.220721, mean_absolute_error: 0.790911, mean_q: 1.000000
#   38980/1000000: episode: 20, duration: 7.108s, episode steps: 1949, steps per second: 274, episode reward: 29.400, mean reward: 0.015 [-265.200, 168.700], mean action: 0.685 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 28.809292, mean_absolute_error: 0.991458, mean_q: 1.000000
#   40929/1000000: episode: 21, duration: 6.137s, episode steps: 1949, steps per second: 318, episode reward: 192.100, mean reward: 0.099 [-83.500, 265.900], mean action: 0.854 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 30.777754, mean_absolute_error: 1.012682, mean_q: 1.000000
#   42878/1000000: episode: 22, duration: 8.832s, episode steps: 1949, steps per second: 221, episode reward: -435.900, mean reward: -0.224 [-211.600, 103.400], mean action: 0.322 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 26.586062, mean_absolute_error: 0.949297, mean_q: 1.000000
#   44827/1000000: episode: 23, duration: 9.818s, episode steps: 1949, steps per second: 199, episode reward: -187.400, mean reward: -0.096 [-234.100, 142.400], mean action: 0.181 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 22.725652, mean_absolute_error: 0.924268, mean_q: 1.000000
#   46776/1000000: episode: 24, duration: 8.670s, episode steps: 1949, steps per second: 225, episode reward: -393.000, mean reward: -0.202 [-134.900, 69.800], mean action: 0.140 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 69.500716, mean_absolute_error: 1.329037, mean_q: 1.000000
#   48725/1000000: episode: 25, duration: 8.241s, episode steps: 1949, steps per second: 236, episode reward: 454.100, mean reward: 0.233 [-80.400, 148.700], mean action: 0.475 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 14.105770, mean_absolute_error: 0.813906, mean_q: 1.000000
#   50674/1000000: episode: 26, duration: 8.274s, episode steps: 1949, steps per second: 236, episode reward: 113.700, mean reward: 0.058 [-149.400, 217.800], mean action: 0.288 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 21.385493, mean_absolute_error: 0.856094, mean_q: 1.000000
#   52623/1000000: episode: 27, duration: 7.875s, episode steps: 1949, steps per second: 248, episode reward: -235.600, mean reward: -0.121 [-228.400, 174.800], mean action: 0.257 [0.000, 1.000], mean observation: 0.157 [-0.973, 0.985], loss: 19.372808, mean_absolute_error: 0.948706, mean_q: 1.000000

# %% [markdown]
# ## Test

# %%
no = 13
agent.load_weights('dqn_weights_{}_final.h5f'.format(no))

# %%
env_test = gym.make('forex-v0', frame_bound=(50,2000), window_size=10)
env_test.trade_fee = 0
env_test.reset()
# Out:
# array([[ 1.04663e+00,  0.00000e+00],
#        [ 1.04666e+00,  3.00000e-05],
#        [ 1.04738e+00,  7.20000e-04],
#        [ 1.04725e+00, -1.30000e-04],
#        [ 1.04705e+00, -2.00000e-04],
#        [ 1.04668e+00, -3.70000e-04],
#        [ 1.04619e+00, -4.90000e-04],
#        [ 1.04610e+00, -9.00000e-05],
#        [ 1.04610e+00,  0.00000e+00],
#        [ 1.04552e+00, -5.80000e-04]])

# %%
agent.test(env_test,visualize=False)
# Out:
# Testing for 1 episodes ...
# Episode 1: reward: 1295.000, steps: 6200

# %%
import matplotlib.pyplot as plt
print(env_test.max_possible_profit())
plt.cla()
env_test.render_all()
plt.show()
# Out:
# 6.243722516486863

# %% [markdown]
# ## plot train graph

# %%
import pandas
no = 9

csv_data = pandas.read_csv('dqn_log_{}.csv'.format(no), delimiter=',', header=None)
plt.plot(csv_data[0],csv_data[2])
